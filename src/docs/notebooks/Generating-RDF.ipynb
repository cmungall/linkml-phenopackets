# %% [markdown]
# # Generating RDF from Phenopackets
#
# One of the advantages of LinkML is automated conversion between different serialization forms of Phenopackets:
#
# - YAML/JSON
# - RDF
# - SQL Databases
#
# In this notebook we'll demonstrate conversion to RDF. We will use LinkML conversion libraries via Python, but all
# this can also be done via the command line.

# %% [markdown]
# ## Import libraries
#
# We will use the (autogenerated) Phenopacket python classes, plus the LinkML loaders and dumpers.
#
# See [Data Conversion](https://linkml.io/linkml/data/conversion.html) in the LinkML docs for more information.

# %%
from phenopackets.datamodel.phenopackets import Phenopacket
from linkml_runtime.loaders import json_loader

# %% [markdown]
# We'll use the generic LinkML json_loader:

# %%
pkt = json_loader.load("../../../examples/Phenopacket-retinoblastoma.json", Phenopacket)

# %% [markdown]
# Let's print out the features as a basic sanity check

# %%
for pf in pkt.phenotypicFeatures:
    print(f" {pf.type.id} {pf.type.label}")
# Out:
#  HP:0030084 Clinodactyly
#  HP:0000555 Leukocoria
#  HP:0000486 Strabismus
#  HP:0000541 Retinal detachment

# %% [markdown]
# ## Dumping to RDF
#
# We will first import the RDF dumper. This is a generic dumper from LinkML - there is no phenopackets-specific dumper.
#
# We will also need to use the SchemaView library to load the Phenopackets schema, as the RDF dumper nees this metadata.

# %%
from phenopackets.datamodel import MAIN_SCHEMA_PATH
from linkml_runtime import SchemaView

sv = SchemaView(str(MAIN_SCHEMA_PATH))

# %% [markdown]
# We will also provide a *prefix map*

# %%
prefix_map = {
    "HP": "http://purl.obolibrary.org/obo/HP_",
    "ex": "https://example.org/",
    "MONDO": "http://purl.obolibrary.org/obo/MONDO_",
    "NCBITaxon": "http://purl.obolibrary.org/obo/NCBITaxon_",
    "NCIT": "http://purl.obolibrary.org/obo/NCIT_",
    "EFO": "http://www.ebi.ac.uk/efo/EFO_",
    "PMID": "https://www.ncbi.nlm.nih.gov/pubmed/",
    "OMIM": "http://omim.org/entry/",
    "GENO": "http://purl.obolibrary.org/obo/GENO_",
    "ECO": "http://purl.obolibrary.org/obo/ECO_",
    "DOI": "https://doi.org/",
    "DrugCentral": "http://identifiers.org/drugcentral/",
    "LOINC": "https://loinc.org/",
    "UCUM": "http://unitsofmeasure.org/",
    "PATO": "http://purl.obolibrary.org/obo/PATO_",
    "CHEBI": "http://purl.obolibrary.org/obo/CHEBI_",
    "SCTID": "http://snomed.info/id/",
    "SNOMEDCT": "http://snomed.info/id/",
    "UO": "http://purl.obolibrary.org/obo/UO_",
    "__base": "https://example.org/base/",
}

# %%
from linkml_runtime.dumpers import rdflib_dumper

print(rdflib_dumper.dumps(pkt, schemaview=sv, prefix_map=prefix_map))
# Out:
# @prefix DrugCentral: <http://identifiers.org/drugcentral/> .
# @prefix GENO: <http://purl.obolibrary.org/obo/GENO_> .
# @prefix HP: <http://purl.obolibrary.org/obo/HP_> .
# @prefix LOINC: <https://loinc.org/> .
# @prefix NCIT: <http://purl.obolibrary.org/obo/NCIT_> .
# @prefix UBERON: <http://purl.obolibrary.org/obo/UBERON_> .
# @prefix UCUM: <http://unitsofmeasure.org/> .
# @prefix ns1: <meta_data:> .
# @prefix ns10: <biosample:> .
# @prefix ns11: <individual:> .
# @prefix ns2: <measurement:> .
# @prefix ns3: <phenotypic_feature:> .
# @prefix ns4: <base:> .
# @prefix ns5: <interpretation:> .
# @prefix ns6: <vrsatile:> .
# @prefix ns7: <vrs:> .
# @prefix ns8: <medical_action:> .
# @prefix ns9: <disease:> .
# @prefix phenopackets: <https://w3id.org/linkml/phenopackets/phenopackets/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# DrugCentral:1678 a ns4:OntologyClass ;
#     ns4:label "melphalan" .
#
# GENO:0000135 a ns4:OntologyClass ;
#     ns4:label "heterozygous" .
#
# HP:0000486 a ns4:OntologyClass ;
#     ns4:label "Strabismus" .
#
# HP:0000541 a ns4:OntologyClass ;
#     ns4:label "Retinal detachment" .
#
# HP:0000555 a ns4:OntologyClass ;
#     ns4:label "Leukocoria" .
#
# HP:0012834 a ns4:OntologyClass ;
#     ns4:label "Right" .
#
# HP:0025637 a ns4:OntologyClass ;
#     ns4:label "Vasospasm" .
#
# HP:0030084 a ns4:OntologyClass ;
#     ns4:label "Clinodactyly" .
#
# NCIT:C10894 a ns4:OntologyClass ;
#     ns4:label "Carboplatin/Etoposide/Vincristine" .
#
# NCIT:C132485 a ns4:OntologyClass ;
#     ns4:label "Apoptosis and Necrosis" .
#
# NCIT:C140678 a ns4:OntologyClass ;
#     ns4:label "Retinoblastoma cM0 TNM Finding v8" .
#
# NCIT:C140711 a ns4:OntologyClass ;
#     ns4:label "Retinoblastoma pN0 TNM Finding v8" .
#
# NCIT:C140720 a ns4:OntologyClass ;
#     ns4:label "Retinoblastoma pT3 TNM Finding v8" .
#
# NCIT:C35941 a ns4:OntologyClass ;
#     ns4:label "Flexner-Wintersteiner Rosette Formation" .
#
# NCIT:C38222 a ns4:OntologyClass ;
#     ns4:label "Intraarterial Route of Administration" .
#
# NCIT:C41331 a ns4:OntologyClass ;
#     ns4:label "Adverse Event" .
#
# NCIT:C64576 a ns4:OntologyClass ;
#     ns4:label "Once" .
#
# NCIT:C8509 a ns4:OntologyClass ;
#     ns4:label "Primary Neoplasm" .
#
# UBERON:0000970 a ns4:OntologyClass ;
#     ns4:label "eye" .
#
# UCUM:mg.kg-1 a ns4:OntologyClass ;
#     ns4:label "milligram per kilogram" .
#
# UCUM:mm a ns4:OntologyClass ;
#     ns4:label "millimeter" .
#
# LOINC:33728-7 a ns4:OntologyClass ;
#     ns4:label "Size.maximum dimension in Tumor" .
#
# LOINC:79892-6 a ns4:OntologyClass ;
#     ns4:label "Right eye Intraocular pressure" .
#
# LOINC:79893-4 a ns4:OntologyClass ;
#     ns4:label "Left eye Intraocular pressure" .
#
# LOINC:LA24739-7 a ns4:OntologyClass ;
#     ns4:label "Group E" .
#
# NCIT:C48601 a ns4:OntologyClass ;
#     ns4:label "Enucleation" .
#
# <http://unitsofmeasure.org/mm[Hg]> a ns4:OntologyClass ;
#     ns4:label "millimetres of mercury" .
#
# LOINC:56844-4 a ns4:OntologyClass ;
#     ns4:label "Intraocular pressure of Eye" .
#
# HP:0012835 a ns4:OntologyClass ;
#     ns4:label "Left" .
#
# NCIT:C62220 a ns4:OntologyClass ;
#     ns4:label "Cure" .
#
# UBERON:0004548 a ns4:OntologyClass ;
#     ns4:label "left eye" .
#
# NCIT:C7541 a ns4:OntologyClass ;
#     ns4:label "Retinoblastoma" .
#
# [] a phenopackets:Phenopacket ;
#     phenopackets:biosamples [ a ns10:Biosample ;
#             ns10:files [ a ns4:File ;
#                     ns4:uri "file://data/fileSomaticWgs.vcf.gz" ] ;
#             ns10:id "biosample.1" ;
#             ns10:measurements [ a ns2:Measurement ;
#                     ns2:assay LOINC:33728-7 ;
#                     ns2:timeObserved [ a ns4:TimeElement ;
#                             ns4:age [ a ns4:Age ;
#                                     ns4:iso8601duration "P8M2W" ] ] ;
#                     ns2:value [ a ns2:Value ;
#                             ns2:quantity [ a ns2:Quantity ;
#                                     ns2:unit UCUM:mm ;
#                                     ns2:value 1.5e+01 ] ] ] ;
#             ns10:pathologicalTnmFinding NCIT:C140711,
#                 NCIT:C140720 ;
#             ns10:phenotypicFeatures [ a ns3:PhenotypicFeature ;
#                     ns3:excluded false ;
#                     ns3:type NCIT:C132485 ],
#                 [ a ns3:PhenotypicFeature ;
#                     ns3:excluded false ;
#                     ns3:type NCIT:C35941 ] ;
#             ns10:procedure [ a ns4:Procedure ;
#                     ns4:bodySite UBERON:0004548 ;
#                     ns4:code NCIT:C48601 ;
#                     ns4:performed [ a ns4:TimeElement ;
#                             ns4:age [ a ns4:Age ;
#                                     ns4:iso8601duration "P8M2W" ] ] ] ;
#             ns10:sampledTissue UBERON:0000970 ;
#             ns10:tumorProgression NCIT:C8509 ] ;
#     phenopackets:diseases [ a ns9:Disease ;
#             ns9:clinicalTnmFinding NCIT:C140678 ;
#             ns9:diseaseStage LOINC:LA24739-7 ;
#             ns9:excluded false ;
#             ns9:onset [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P4M" ] ] ;
#             ns9:primarySite UBERON:0004548 ;
#             ns9:term NCIT:C7541 ] ;
#     phenopackets:files [ a ns4:File ;
#             ns4:uri "file://data/germlineWgs.vcf.gz" ] ;
#     phenopackets:id "arbitrary.id" ;
#     phenopackets:interpretations [ a ns5:Interpretation ;
#             ns5:diagnosis [ a ns5:Diagnosis ;
#                     ns5:disease NCIT:C7541 ;
#                     ns5:genomicInterpretations [ a ns5:GenomicInterpretation ;
#                             ns5:interpretationStatus "CAUSATIVE" ;
#                             ns5:subjectOrBiosampleId "proband A" ;
#                             ns5:variantInterpretation [ a ns5:VariantInterpretation ;
#                                     ns5:acmgPathogenicityClassification "PATHOGENIC" ;
#                                     ns5:therapeuticActionability "ACTIONABLE" ;
#                                     ns5:variationDescriptor [ a ns6:VariationDescriptor ;
#                                             ns6:extensions [ a ns6:Extension ;
#                                                     ns6:name "mosaicism" ;
#                                                     ns6:value "40.0%" ] ;
#                                             ns6:id "variant-id" ;
#                                             ns6:moleculeContext "unspecified_molecule_context" ;
#                                             ns6:variation [ a ns7:Variation ;
#                                                     ns7:copyNumber [ a ns7:CopyNumber ;
#                                                             ns7:derivedSequenceExpression [ a ns7:DerivedSequenceExpression ;
#                                                                     ns7:location [ a ns7:SequenceLocation ;
#                                                                             ns7:sequenceId "refseq:NC_000013.14" ;
#                                                                             ns7:sequenceInterval [ a ns7:SequenceInterval ;
#                                                                                     ns7:endNumber [ a ns7:Number ;
#                                                                                             ns7:value 61706822 ] ;
#                                                                                     ns7:startNumber [ a ns7:Number ;
#                                                                                             ns7:value 25981249 ] ] ] ;
#                                                                     ns7:reverseComplement false ] ;
#                                                             ns7:number [ a ns7:Number ;
#                                                                     ns7:value 1 ] ] ] ] ] ],
#                         [ a ns5:GenomicInterpretation ;
#                             ns5:interpretationStatus "CAUSATIVE" ;
#                             ns5:subjectOrBiosampleId "biosample.1" ;
#                             ns5:variantInterpretation [ a ns5:VariantInterpretation ;
#                                     ns5:acmgPathogenicityClassification "PATHOGENIC" ;
#                                     ns5:therapeuticActionability "ACTIONABLE" ;
#                                     ns5:variationDescriptor [ a ns6:VariationDescriptor ;
#                                             ns6:allelicState GENO:0000135 ;
#                                             ns6:expressions [ a ns6:Expression ;
#                                                     ns6:syntax "hgvs.c" ;
#                                                     ns6:value "NM_000321.2:c.958C>T" ],
#                                                 [ a ns6:Expression ;
#                                                     ns6:syntax "transcript_reference" ;
#                                                     ns6:value "NM_000321.2" ] ;
#                                             ns6:extensions [ a ns6:Extension ;
#                                                     ns6:name "allele-frequency" ;
#                                                     ns6:value "25.0%" ] ;
#                                             ns6:geneContext [ a ns6:GeneDescriptor ;
#                                                     ns6:symbol "RB1" ;
#                                                     ns6:valueId "HGNC:9884" ] ;
#                                             ns6:id "rs121913300" ;
#                                             ns6:label "RB1 c.958C>T (p.Arg320Ter)" ;
#                                             ns6:moleculeContext "genomic" ;
#                                             ns6:variation [ a ns7:Variation ;
#                                                     ns7:allele [ a ns7:Allele ;
#                                                             ns7:literalSequenceExpression [ a ns7:LiteralSequenceExpression ;
#                                                                     ns7:sequence "T" ] ;
#                                                             ns7:sequenceLocation [ a ns7:SequenceLocation ;
#                                                                     ns7:sequenceId "refseq:NC_000013.11" ;
#                                                                     ns7:sequenceInterval [ a ns7:SequenceInterval ;
#                                                                             ns7:endNumber [ a ns7:Number ;
#                                                                                     ns7:value 48367512 ] ;
#                                                                             ns7:startNumber [ a ns7:Number ;
#                                                                                     ns7:value 48367511 ] ] ] ] ] ;
#                                             ns6:vcfRecord [ a ns6:VcfRecord ;
#                                                     ns6:alt "T" ;
#                                                     ns6:chrom "NC_000013.11" ;
#                                                     ns6:genomeAssembly "GRCh38" ;
#                                                     ns6:pos 48367512 ;
#                                                     ns6:ref "C" ] ] ] ] ] ;
#             ns5:id "interpretation.id" ;
#             ns5:progressStatus "SOLVED" ] ;
#     phenopackets:measurements [ a ns2:Measurement ;
#             ns2:assay LOINC:79892-6 ;
#             ns2:timeObserved [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P6M" ] ] ;
#             ns2:value [ a ns2:Value ;
#                     ns2:quantity [ a ns2:Quantity ;
#                             ns2:referenceRange [ a ns2:ReferenceRange ;
#                                     ns2:high 2.1e+01 ;
#                                     ns2:low 1e+01 ;
#                                     ns2:unit LOINC:56844-4 ] ;
#                             ns2:unit <http://unitsofmeasure.org/mm[Hg]> ;
#                             ns2:value 1.5e+01 ] ] ],
#         [ a ns2:Measurement ;
#             ns2:assay LOINC:79893-4 ;
#             ns2:timeObserved [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P6M" ] ] ;
#             ns2:value [ a ns2:Value ;
#                     ns2:quantity [ a ns2:Quantity ;
#                             ns2:referenceRange [ a ns2:ReferenceRange ;
#                                     ns2:high 2.1e+01 ;
#                                     ns2:low 1e+01 ;
#                                     ns2:unit LOINC:56844-4 ] ;
#                             ns2:unit <http://unitsofmeasure.org/mm[Hg]> ;
#                             ns2:value 2.5e+01 ] ] ] ;
#     phenopackets:medicalActions [ a ns8:MedicalAction ;
#             ns8:adverseEvents HP:0025637 ;
#             ns8:treatment [ a ns8:Treatment ;
#                     ns8:agent DrugCentral:1678 ;
#                     ns8:doseIntervals [ a ns8:DoseInterval ;
#                             ns8:interval [ a ns4:TimeInterval ;
#                                     ns4:end "2020-09-02T00:00:00Z" ;
#                                     ns4:start "2020-09-02T00:00:00Z" ] ;
#                             ns8:quantity [ a ns2:Quantity ;
#                                     ns2:unit UCUM:mg.kg-1 ;
#                                     ns2:value 4e-01 ] ;
#                             ns8:scheduleFrequency NCIT:C64576 ] ;
#                     ns8:drugType "UNKNOWN_DRUG_TYPE" ;
#                     ns8:routeOfAdministration NCIT:C38222 ] ;
#             ns8:treatmentIntent NCIT:C62220 ;
#             ns8:treatmentTarget NCIT:C7541 ;
#             ns8:treatmentTerminationReason NCIT:C41331 ],
#         [ a ns8:MedicalAction ;
#             ns8:therapeuticRegimen [ a ns8:TherapeuticRegimen ;
#                     ns8:endTime [ a ns4:TimeElement ;
#                             ns4:age [ a ns4:Age ;
#                                     ns4:iso8601duration "P8M" ] ] ;
#                     ns8:ontologyClass NCIT:C10894 ;
#                     ns8:regimenStatus "COMPLETED" ;
#                     ns8:startTime [ a ns4:TimeElement ;
#                             ns4:age [ a ns4:Age ;
#                                     ns4:iso8601duration "P7M" ] ] ] ;
#             ns8:treatmentIntent NCIT:C62220 ;
#             ns8:treatmentTarget NCIT:C7541 ],
#         [ a ns8:MedicalAction ;
#             ns8:procedure [ a ns4:Procedure ;
#                     ns4:bodySite UBERON:0004548 ;
#                     ns4:code NCIT:C48601 ;
#                     ns4:performed [ a ns4:TimeElement ;
#                             ns4:age [ a ns4:Age ;
#                                     ns4:iso8601duration "P8M2W" ] ] ] ;
#             ns8:treatmentIntent NCIT:C62220 ;
#             ns8:treatmentTarget NCIT:C7541 ] ;
#     phenopackets:metaData [ a ns1:MetaData ;
#             ns1:created "2021-05-14T10:35:00Z" ;
#             ns1:createdBy "anonymous biocurator" ;
#             ns1:phenopacketSchemaVersion "2.0.0" ;
#             ns1:resources [ a ns1:Resource ;
#                     ns1:id "drugcentral" ;
#                     ns1:iriPrefix "https://drugcentral.org/drugcard/" ;
#                     ns1:name "Drug Central" ;
#                     ns1:namespacePrefix "DrugCentral" ;
#                     ns1:url "https://drugcentral.org/" ;
#                     ns1:version "2022-08-22" ],
#                 [ a ns1:Resource ;
#                     ns1:id "uberon" ;
#                     ns1:iriPrefix "http://purl.obolibrary.org/obo/UBERON_" ;
#                     ns1:name "Uber-anatomy ontology" ;
#                     ns1:namespacePrefix "UBERON" ;
#                     ns1:url "http://purl.obolibrary.org/obo/uberon.owl" ;
#                     ns1:version "2021-07-27" ],
#                 [ a ns1:Resource ;
#                     ns1:id "efo" ;
#                     ns1:iriPrefix "http://purl.obolibrary.org/obo/EFO_" ;
#                     ns1:name "Experimental Factor Ontology" ;
#                     ns1:namespacePrefix "EFO" ;
#                     ns1:url "http://www.ebi.ac.uk/efo/efo.owl" ;
#                     ns1:version "3.34.0" ],
#                 [ a ns1:Resource ;
#                     ns1:id "ncbitaxon" ;
#                     ns1:iriPrefix "http://purl.obolibrary.org/obo/NCBITaxon_" ;
#                     ns1:name "NCBI organismal classification" ;
#                     ns1:namespacePrefix "NCBITaxon" ;
#                     ns1:url "http://purl.obolibrary.org/obo/ncbitaxon.owl" ;
#                     ns1:version "2021-06-10" ],
#                 [ a ns1:Resource ;
#                     ns1:id "hp" ;
#                     ns1:iriPrefix "http://purl.obolibrary.org/obo/HP_" ;
#                     ns1:name "human phenotype ontology" ;
#                     ns1:namespacePrefix "HP" ;
#                     ns1:url "http://purl.obolibrary.org/obo/hp.owl" ;
#                     ns1:version "2022-06-11" ],
#                 [ a ns1:Resource ;
#                     ns1:id "ucum" ;
#                     ns1:iriPrefix "https://units-of-measurement.org/" ;
#                     ns1:name "Unified Code for Units of Measure" ;
#                     ns1:namespacePrefix "UCUM" ;
#                     ns1:url "https://ucum.org" ;
#                     ns1:version "2.1" ],
#                 [ a ns1:Resource ;
#                     ns1:id "geno" ;
#                     ns1:iriPrefix "http://purl.obolibrary.org/obo/GENO_" ;
#                     ns1:name "Genotype Ontology" ;
#                     ns1:namespacePrefix "GENO" ;
#                     ns1:url "http://purl.obolibrary.org/obo/geno.owl" ;
#                     ns1:version "2022-03-05" ],
#                 [ a ns1:Resource ;
#                     ns1:id "loinc" ;
#                     ns1:iriPrefix "https://loinc.org/" ;
#                     ns1:name "Logical Observation Identifiers Names and Codes" ;
#                     ns1:namespacePrefix "LOINC" ;
#                     ns1:url "https://loinc.org" ;
#                     ns1:version "2.73" ],
#                 [ a ns1:Resource ;
#                     ns1:id "ncit" ;
#                     ns1:iriPrefix "http://purl.obolibrary.org/obo/NCIT_" ;
#                     ns1:name "NCI Thesaurus" ;
#                     ns1:namespacePrefix "NCIT" ;
#                     ns1:url "http://purl.obolibrary.org/obo/ncit.owl" ;
#                     ns1:version "21.05d" ] ] ;
#     phenopackets:phenotypicFeatures [ a ns3:PhenotypicFeature ;
#             ns3:excluded false ;
#             ns3:modifiers HP:0012835 ;
#             ns3:onset [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P5M15D" ] ] ;
#             ns3:type HP:0000486 ],
#         [ a ns3:PhenotypicFeature ;
#             ns3:excluded false ;
#             ns3:modifiers HP:0012834 ;
#             ns3:onset [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P3M" ] ] ;
#             ns3:type HP:0030084 ],
#         [ a ns3:PhenotypicFeature ;
#             ns3:excluded false ;
#             ns3:modifiers HP:0012835 ;
#             ns3:onset [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P4M" ] ] ;
#             ns3:type HP:0000555 ],
#         [ a ns3:PhenotypicFeature ;
#             ns3:excluded false ;
#             ns3:modifiers HP:0012835 ;
#             ns3:onset [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P6M" ] ] ;
#             ns3:type HP:0000541 ] ;
#     phenopackets:subject [ a ns11:Individual ;
#             ns11:id "proband A" ;
#             ns11:karyotypicSex "XX" ;
#             ns11:sex "FEMALE" ;
#             ns11:timeAtLastEncounter [ a ns4:TimeElement ;
#                     ns4:age [ a ns4:Age ;
#                             ns4:iso8601duration "P6M" ] ] ] .
